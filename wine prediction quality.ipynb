# %%
# now in this project i would like to predict the wine quality
# first import the modules 
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\John\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\John\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
# C:\Users\John\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
#now import the dataset
df=pd.read_csv("winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# now take first rows
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
#now check the datatype of attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#let us check any missed values or not
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#there is no missing values above dataset

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
#let us count the target variable(quality)
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
#now visualization the dataset
#EDA(expolatory data anaysis)
import matplotlib.pyplot as plt
df.hist(bins=20, figsize=(10, 10))
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(df['quality'],df['alcohol'])
plt.xlabel('quality')
plt.ylabel('alcohol')
plt.show()

# %%
#now visualize using heat map
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(df.corr()>0.7,annot=True, cbar=False)
plt.show()
#see the heatmap below all are equal correlated features

# %%
#in this dataset target variable (i.e dependent variable )is quality
#so now drop the column from the dataset
x=df.drop('quality',axis=1)
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y=df['quality']
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
#now split the dataset
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=60,stratify=y)

# %%
x_train,x_train.shape
# Out:
# (      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
#  1440            7.2             0.370         0.32             2.0      0.062
#  1396            8.7             0.675         0.10             1.6      0.090
#  1550            7.1             0.680         0.00             2.3      0.087
#  1044            6.4             0.390         0.33             3.3      0.046
#  1253            7.9             0.660         0.00             1.4      0.096
#  ...             ...               ...          ...             ...        ...
#  676            10.8             0.400         0.41             2.2      0.084
#  1086            8.5             0.340         0.40             4.7      0.055
#  86              8.6             0.490         0.28             1.9      0.110
#  988             7.7             0.390         0.12             1.7      0.097
#  1028            7.2             0.340         0.21             2.5      0.075
#
# ...

# %%
x_test,x_test.shape
# Out:
# (      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
#  634             7.9              0.35         0.21             1.9      0.073
#  1482            7.2              0.58         0.54             2.1      0.114
#  434            10.4              0.41         0.55             3.2      0.076
#  892            10.1              0.45         0.23             1.9      0.082
#  1558            6.9              0.63         0.33             6.7      0.235
#  ...             ...               ...          ...             ...        ...
#  9               7.5              0.50         0.36             6.1      0.071
#  1007            9.1              0.30         0.34             2.0      0.064
#  425             6.6              0.84         0.03             2.3      0.059
#  177             7.5              0.52         0.42             2.3      0.087
#  1038            8.7              0.41         0.41             6.2      0.078
#
# ...

# %%
y_train,y_train.shape
# Out:
# (1440    7
#  1396    5
#  1550    5
#  1044    6
#  1253    5
#         ..
#  676     6
#  1086    7
#  86      6
#  988     5
#  1028    6
#  Name: quality, Length: 1279, dtype: int64,
#  (1279,))

# %%
#define import modules thw modules 

from sklearn.linear_model import LogisticRegression

# %%
#apply the model
# from sklearn.linear_model import LinearRegression
regr=LogisticRegression()
#fit the model
regr.fit(x_train,y_train)
#predict thhe model
xtrainprediction=regr.predict(x_train)
xtrainprediction
# Out:
# array([6, 5, 5, ..., 5, 6, 6], dtype=int64)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy=accuracy_score(xtrainprediction,y_train)
accuracy
# Out:
# 0.5871774824081314

# %%
import pickle
pickle.dump(regr, open('mymodel', 'wb'))

# %%
model= pickle.load(open('mymodel', 'rb'))
model= pickle.load(open('mymodel', 'rb'))
model.predict(x_train),model.predict(x_train).shape
# Out:
# (array([6, 5, 5, ..., 5, 6, 6], dtype=int64), (1279,))

# %%
# !pip install gradio
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# ...

# %%
pip install fsspec --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)

# %%
import gradio
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 import gradio
#
# File ~\anaconda3\lib\site-packages\gradio\__init__.py:3, in <module>
#       1 import pkgutil
# ----> 3 import gradio.components as components
#       4 import gradio.inputs as inputs
#       5 import gradio.outputs as outputs
#
# File ~\anaconda3\lib\site-packages\gradio\components\__init__.py:1, in <module>
# ----> 1 from gradio.components.annotated_image import AnnotatedImage
#       2 from gradio.components.audio import Audio
#       3 from gradio.components.bar_plot import BarPlot
#
# File ~\anaconda3\lib\site-packages\gradio\components\annotated_image.py:14, in <module>
#      11 from PIL import Image as _Image  # using _ to minimize namespace pollution
#      13 from gradio import utils
# ---> 14 from gradio.components.base import IOComponent, _Keywords
# ...

# %%
# !pip install gradio-3.9

# %%
def make_prediction(fixedacidity,volatileacid,ititricacid,residualsugar,chlorides,freesulfurdioxide,totalsulfurdioxide,density,pH,sulphates,alcohol):
    model= pickle.load(open('mymodel', 'rb'))
    predictedwinequality = model.predict([[fixedacidity,volatileacid,ititricacid,residualsugar,chlorides,freesulfurdioxide,totalsulfurdioxide,density,pH,sulphates,alcohol]])
    return predictedwinequality

#Create the input component for Gradio since we are expecting 4 inputs

fixedacidity_input = gr.Number(label = "Enter  fixed acidity")
volatileacid_input = gr.Number(label= "enter volatile acid  ")
ititricacid_input = gr.Number(label= "enter ititric acid  ")
reisdualsugar_input = gr.Number(label= "enter residualsugar acid  ")

chlorides_input = gr.Number(label= "enter chlorides ")
freesulfurdioxide_input = gr.Number(label= "enter free sulfur dioxide")
totalsulfurdioxid_input = gr.Number(label= "enter total sulfur dioxid  ")
density_input = gr.Number(label= "enter density  ")
pH_input = gr.Number(label= "enter pH  ")
sulphates_input = gr.Number(label= "enter sulphates ")
alcohol_input = gr.Number(label= "enter sulphates ")
# We create the output
output = gr.Textbox()


app = gr.Interface(fn = make_prediction, inputs=[fixedacidity_input,volatileacid_input,reisdualsugar_input,ititricacid_input,chlorides_input,freesulfurdioxide_input,totalsulfurdioxid_input,density_input,pH_input,sulphates_input,alcohol_input], outputs=output)
app.launch(share=True)

# %%
pip install gradio==3.50
# Out:
# ...
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio-client 0.2.1
#     Uninstalling gradio-client-0.2.1:
#       Successfully uninstalled gradio-client-0.2.1
#   Attempting uninstall: gradio
#     Found existing installation: gradio 3.28.3
#     Uninstalling gradio-3.28.3:
#       Successfully uninstalled gradio-3.28.3
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\john\anaconda3\lib\site-packages)
# ...

# %%
pip uninstall fsspec

# %%
pip install fsspec==2022.10.0
